# %%
import benders
import datetime

# %%
# Customer number
n = 30
# Facility candidates
m = 3
# Instance save to local file name
fileName = "test.txt"
# Generate instance
instance = benders.generateInstance(n, m, fileName)

# %%
instance
# Out:
# {'n': 30,
#  'm': 3,
#  'c': {(0, 0): 75,
#   (0, 1): 118,
#   (0, 2): 95,
#   (1, 0): 83,
#   (1, 1): 185,
#   (1, 2): 135,
#   (2, 0): 52,
#   (2, 1): 94,
#   (2, 2): 170,
#   (3, 0): 186,
#   (3, 1): 169,
#   (3, 2): 189,
#   (4, 0): 157,
#   (4, 1): 156,
#   (4, 2): 155,
#   (5, 0): 98,
#   (5, 1): 150,
#   (5, 2): 96,
#   (6, 0): 155,
#   (6, 1): 145,
#   (6, 2): 170,
#   (7, 0): 178,
#   (7, 1): 50,
#   (7, 2): 139,
#   (8, 0): 87,
#   (8, 1): 193,
#   (8, 2): 167,
#   (9, 0): 118,
#   (9, 1): 63,
#   (9, 2): 195,
#   (10, 0): 188,
#   (10, 1): 133,
#   (10, 2): 193,
#   (11, 0): 70,
#   (11, 1): 93,
#   (11, 2): 88,
#   (12, 0): 117,
#   (12, 1): 105,
#   (12, 2): 191,
#   (13, 0): 141,
#   (13, 1): 157,
#   (13, 2): 165,
#   (14, 0): 182,
#   (14, 1): 171,
#   (14, 2): 117,
#   (15, 0): 183,
#   (15, 1): 151,
#   (15, 2): 85,
#   (16, 0): 194,
#   (16, 1): 175,
#   (16, 2): 77,
#   (17, 0): 199,
#   (17, 1): 107,
#   (17, 2): 125,
#   (18, 0): 122,
#   (18, 1): 199,
#   (18, 2): 185,
#   (19, 0): 188,
#   (19, 1): 67,
#   (19, 2): 198,
#   (20, 0): 86,
#   (20, 1): 183,
#   (20, 2): 67,
#   (21, 0): 135,
#   (21, 1): 108,
#   (21, 2): 103,
#   (22, 0): 52,
#   (22, 1): 51,
#   (22, 2): 118,
#   (23, 0): 81,
#   (23, 1): 83,
#   (23, 2): 85,
#   (24, 0): 97,
#   (24, 1): 78,
#   (24, 2): 144,
#   (25, 0): 177,
#   (25, 1): 140,
#   (25, 2): 147,
#   (26, 0): 103,
#   (26, 1): 84,
#   (26, 2): 110,
#   (27, 0): 111,
#   (27, 1): 154,
#   (27, 2): 61,
#   (28, 0): 83,
#   (28, 1): 89,
#   (28, 2): 112,
#   (29, 0): 179,
#   (29, 1): 139,
#   (29, 2): 146},
#  'd': {0: 2493, 1: 1997, 2: 1147}}

# %%
# Read instance from local file (easier to repeat)
instance = benders.readInstance(fileName)

# %%
# Directly use gruobi, which is extremely fast
# This is not for comparison, gurobi are using some high-level techniques
# This is for validating the optimal solution
benders.directSolveProblem(instance)
# Out:
# Academic license - for non-commercial use only
# Optimize a model with 120 rows, 93 columns and 270 nonzeros
# Variable types: 90 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [5e+01, 2e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 120 rows, 93 columns, 270 nonzeros
# Variable types: 90 continuous, 3 integer (3 binary)
#
# Root relaxation: objective 5.175000e+03, 91 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5175.0000000 5175.00000  0.00%     -    0s
#
# Explored 0 nodes (91 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 5175
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.175000000000e+03, best bound 5.175000000000e+03, gap 0.0000%
# {'ofv': 5175.0, 'y': [2]}

# %%
# Use Pareto-optimal cuts to accelerate
start = datetime.datetime.now()
res = benders.masterProblem(instance)
t = (datetime.datetime.now() - start).total_seconds()
print(res)
print("Total time: ", t)
# Out:
# Changed value of parameter lazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Add feasibility cut
# Add feasibility cut
# Add feasibility cut
# Add feasibility cut
# Add feasibility cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# Add optimality cut
# {'ofv': 30365.999999999996, 'y': [0, 2, 4]}
# Total time:  7.975999
